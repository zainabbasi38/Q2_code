# %% [markdown]
# <a href="https://colab.research.google.com/github/zainabbasi38/Q2_code/blob/main/Project_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install langchain_google_genai
# !pip install langchain-community
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 4.0 MB/s eta 0:00:00
# ...

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain.chains import ConversationChain
from langchain.memory import ConversationBufferMemory
from langchain.schema import SystemMessage
from google.colab import userdata

api_key = userdata.get('GEMINI_API_KEY')

llm = ChatGoogleGenerativeAI(
    api_key=api_key,
    model="gemini-1.5-flash",
    max_tokens=800,
    temperature=0.7
)

system_message = SystemMessage(
    content= "You are a helpful AI asistant and only response about AI"
)


memory = ConversationBufferMemory(return_messages=True)

conversation = ConversationChain(
    llm=llm,
    memory=memory
)

conversation.memory.buffer.append(system_message)
print("I am a AI asistant . Feel free to ask me question about Ai ")
while True:
    try:
        user_input = input("Ask something! ")
        if user_input.lower() == 'exit':
            print("Goodbye! Have a nice day")
            break
        ai_response = conversation.predict(input=user_input)
        print(f"AI: {ai_response}")
    except Exception as e:
        print(f"An error occurred: {e}")
# Out:
# I am a AI asistant . Feel free to ask me question about Ai
# Ask something! Explain AI
# AI: Okay, I'd be happy to explain AI! Let's dive into it.
#
# "AI," or Artificial Intelligence, at its core, refers to the ability of a computer or a robot controlled by a computer to do tasks that are usually done by humans because they require human intelligence and discernment. This is a really broad definition, though, so let's break it down into a few key ideas:
#
# **1. The Goal: Mimicking Human Intelligence**
#
# AI aims to create systems that can:
#
# *   **Learn:**  This involves acquiring information and rules for using that information. This might involve recognizing patterns in data, like a spam filter learning to identify junk email.
# *   **Reason:**  This is about using the learned information to solve problems, make decisions, and draw conclusions. For example, an AI playing chess needs to reason about possible moves.
# ...
